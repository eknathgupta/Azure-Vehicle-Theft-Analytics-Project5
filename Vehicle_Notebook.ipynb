# %%
dbutils.secrets.listScopes()
# Out:
# [SecretScope(name='dbscope')]

# %%
spark.conf.set(
  "fs.azure.account.key.stvehicle.dfs.core.windows.net",
  dbutils.secrets.get(scope="dbscope", key="SAsecret")
)

# %%
bronze_path = "abfss://bronze@stvehicle.dfs.core.windows.net/"
dbutils.fs.ls(bronze_path)
# Out:
# [FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/locations.csv', name='locations.csv', size=732, modificationTime=1767363398000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/make_details.csv', name='make_details.csv', size=2993, modificationTime=1767363410000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles.csv', name='stolen_vehicles.csv', size=226866, modificationTime=1767363424000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles_db_data_dictionary.csv', name='stolen_vehicles_db_data_dictionary.csv', size=866, modificationTime=1767363437000)]

# %%
dbutils.fs.ls(bronze_path)
# Out:
# [FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/locations.csv', name='locations.csv', size=732, modificationTime=1767363398000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/make_details.csv', name='make_details.csv', size=2993, modificationTime=1767363410000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles.csv', name='stolen_vehicles.csv', size=226866, modificationTime=1767363424000),
#  FileInfo(path='abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles_db_data_dictionary.csv', name='stolen_vehicles_db_data_dictionary.csv', size=866, modificationTime=1767363437000)]

# %%
spark.conf.set(
  "fs.azure.account.key.stvehicle.dfs.core.windows.net",
  dbutils.secrets.get(scope="dbscope", key="SAsecret")
)

dbutils.fs.ls("abfss://silver@stvehicle.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/database_stolen_df.csv/', name='database_stolen_df.csv/', size=0, modificationTime=1767705332000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/locations.csv/', name='locations.csv/', size=0, modificationTime=1767705256000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/make_details_df.csv/', name='make_details_df.csv/', size=0, modificationTime=1767705330000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv/', name='stolen_vehicles_df.csv/', size=0, modificationTime=1767705331000)]

# %%
spark.conf.set(
  "fs.azure.account.key.stvehicle.dfs.core.windows.net",
  dbutils.secrets.get(scope="dbscope", key="SAsecret")
)

dbutils.fs.ls("abfss://gold@stvehicle.dfs.core.windows.net/")
# Out:
# [FileInfo(path='abfss://gold@stvehicle.dfs.core.windows.net/database_stolen_df.csv/', name='database_stolen_df.csv/', size=0, modificationTime=1767708626000),
#  FileInfo(path='abfss://gold@stvehicle.dfs.core.windows.net/location_df.csv/', name='location_df.csv/', size=0, modificationTime=1767708553000),
#  FileInfo(path='abfss://gold@stvehicle.dfs.core.windows.net/make_details_df.csv/', name='make_details_df.csv/', size=0, modificationTime=1767708625000),
#  FileInfo(path='abfss://gold@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv/', name='stolen_vehicles_df.csv/', size=0, modificationTime=1767708625000)]

# %%
silver_path = "abfss://silver@stvehicle.dfs.core.windows.net/"
dbutils.fs.ls(silver_path)
# Out:
# [FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/database_stolen_df.csv/', name='database_stolen_df.csv/', size=0, modificationTime=1767705332000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/locations.csv/', name='locations.csv/', size=0, modificationTime=1767705256000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/make_details_df.csv/', name='make_details_df.csv/', size=0, modificationTime=1767705330000),
#  FileInfo(path='abfss://silver@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv/', name='stolen_vehicles_df.csv/', size=0, modificationTime=1767705331000)]

# %%
gold_path = "abfss://gold@stvehicle.dfs.core.windows.net/"
dbutils.fs.ls(gold_path)
display(gold_path)
# Out:
# 'abfss://gold@stvehicle.dfs.core.windows.net/'

# %%
location_df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("abfss://bronze@stvehicle.dfs.core.windows.net/locations.csv")

display(location_df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
location_df.printSchema()
# Out:
# root
#  |-- location_id: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- population: string (nullable = true)
#  |-- density: double (nullable = true)

# %%
make_details_df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("abfss://bronze@stvehicle.dfs.core.windows.net/make_details.csv")

stolen_vehicles_df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles.csv")

database_stolen_df = spark.read.format("csv")\
    .option("header", "true")\
    .option("inferSchema", "true")\
    .load("abfss://bronze@stvehicle.dfs.core.windows.net/stolen_vehicles_db_data_dictionary.csv")

# %%
location_df.printSchema()
# Out:
# root
#  |-- location_id: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- population: string (nullable = true)
#  |-- density: double (nullable = true)

# %%
#here we do pupulation column into intger type
from pyspark.sql.functions import col, regexp_replace

location_df = location_df.withColumn("population", regexp_replace(col("population"),",","").cast("int"))

# %%
location_df.printSchema()
# Out:
# root
#  |-- location_id: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- population: integer (nullable = true)
#  |-- density: double (nullable = true)

# %%
make_details_df.show(1)
# Out:
# +-------+-------------+---------+
# |make_id|    make_name|make_type|
# +-------+-------------+---------+
# |    501|Aakron Xpress| Standard|
# +-------+-------------+---------+
# only showing top 1 row

# %%
make_details_df.printSchema()
# Out:
# root
#  |-- make_id: integer (nullable = true)
#  |-- make_name: string (nullable = true)
#  |-- make_type: string (nullable = true)

# %%
location_df=location_df.toDF(*[column.lower().replace(" ","_") for column in location_df.columns])
make_details_df=make_details_df.toDF(*[column.lower().replace(" ","_") for column in make_details_df.columns])
stolen_vehicles_df =stolen_vehicles_df .toDF(*[column.lower().replace(" ","_") for column in stolen_vehicles_df .columns])
database_stolen_df=database_stolen_df.toDF(*[column.lower().replace(" ","_") for column in database_stolen_df.columns])

# %%
stolen_vehicles_df.show(2)
# Out:
# +----------+------------+-------+----------+-------------------+------+-----------+-----------+
# |vehicle_id|vehicle_type|make_id|model_year|       vehicle_desc| color|date_stolen|location_id|
# +----------+------------+-------+----------+-------------------+------+-----------+-----------+
# |         1|     Trailer|    623|      2021|           BST2021D|Silver| 2021-11-05|        102|
# |         2|Boat Trailer|    623|      2021|OUTBACK BOATS FT470|Silver| 2021-12-13|        105|
# +----------+------------+-------+----------+-------------------+------+-----------+-----------+
# only showing top 2 rows

# %%
location_df.show(2)
database_stolen_df.show(2)
make_details_df.show(2)
stolen_vehicles_df.show(2)
# Out:
# +-----------+---------+-----------+----------+-------+
# |location_id|   region|    country|population|density|
# +-----------+---------+-----------+----------+-------+
# |        101|Northland|New Zealand|    201500|  16.11|
# |        102| Auckland|New Zealand|   1695200| 343.09|
# +-----------+---------+-----------+----------+-------+
# only showing top 2 rows
# +---------------+------------+--------------------+
# |          table|       field|         description|
# +---------------+------------+--------------------+
# |stolen_vehicles|  vehicle_id|Unique ID of a st...|
# |stolen_vehicles|vehicle_type|     Type of vehicle|
# +---------------+------------+--------------------+
# only showing top 2 rows
# +-------+-------------+---------+
# |make_id|    make_name|make_type|
# +-------+-------------+---------+
# |    501|Aakron Xpress| Standard|
# |    502|         ADLY| Standard|
# +-------+-------------+---------+
# only showing top 2 rows
# ...

# %%
make_details_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/make_details_df.csv")
stolen_vehicles_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv")
database_stolen_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/database_stolen_df.csv")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# File <command-6519682310074272>, line 1
# ----> 1 make_details_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/make_details_df.csv")
#       2 stolen_vehicles_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv")
#       3 database_stolen_df.write.option("header","true").csv("abfss://silver@stvehicle.dfs.core.windows.net/database_stolen_df.csv")
#
# File /databricks/spark/python/pyspark/sql/connect/readwriter.py:831, in DataFrameWriter.csv(self, path, mode, compression, sep, quote, escape, header, nullValue, escapeQuotes, quoteAll, dateFormat, timestampFormat, ignoreLeadingWhiteSpace, ignoreTrailingWhiteSpace, charToEscapeQuoteEscaping, encoding, emptyValue, lineSep)
#     812 self.mode(mode)
#     813 self._set_opts(
# ...

# %%
location_df.show(5)

# %%
from pyspark.sql.functions import col, when, sum

# %%
#we have to check any loaction null or not if have any null value then counter with 1

null_count_location = location_df.select([sum(col(column).isNull().cast('int')).alias(column) for column in location_df.columns])

# %%
null_count_make_details = make_details_df.select([sum(col(column).isNull().cast('int')).alias(column) for column in make_details_df.columns])
null_count_stolen_vehicles = stolen_vehicles_df.select([sum(col(column).isNull().cast('int')).alias(column) for column in stolen_vehicles_df.columns])
null_count_database_stolen = database_stolen_df.select([sum(col(column).isNull().cast('int')).alias(column) for column in database_stolen_df.columns])

# %%
null_count_database_stolen.show()
null_count_make_details.show()
null_count_location.show()
null_count_stolen_vehicles.show()

# %%
#replace null value with what they have
stolen_vehicles_df = stolen_vehicles_df.fillna({
    "vehicle_type" : "No data",
    "make_id": 0,
    "Model_year":0,
    "vehicle_desc": "No data",
    "color": "No data"}
   

)

# %%
#now send this data into gold layer
location_df.write.option("header","true").csv("abfss://gold@stvehicle.dfs.core.windows.net/location_df.csv")
make_details_df.write.option("header","true").csv("abfss://gold@stvehicle.dfs.core.windows.net/make_details_df.csv")
stolen_vehicles_df.write.option("header","true").csv("abfss://gold@stvehicle.dfs.core.windows.net/stolen_vehicles_df.csv")
database_stolen_df.write.option("header","true").csv("abfss://gold@stvehicle.dfs.core.windows.net/database_stolen_df.csv")

# %%
#creating temp view
location_df.createOrReplaceTempView("location")
stolen_vehicles_df.createOrReplaceTempView("stolen_vehicles")
database_stolen_df.createOrReplaceTempView("database_stolen")
make_details_df.createOrReplaceTempView("make_details")
